# %%
pwd
# Out:
# 'C:\\Users\\sai dharan'

# %%
import tensorflow as tf
from vit import ViTClassfier
from utils import plot_grid_ds, AttrDict, BalancedSparseCategoricalAccuracy
# Out:
# C:\Users\sai dharan\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\sai dharan\AppData\Local\Temp\ipykernel_13680\1531362466.py", line 2, in <module>
#     from vit import ViTClassfier
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\vit\__init__.py", line 2, in <module>
#     from .application import Application
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\vit\application.py", line 20, in <module>
#     from vit.formatter_base import FormatterBase
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\vit\formatter_base.py", line 8, in <module>
#     from vit import util
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\vit\util.py", line 3, in <module>
#     import curses
#   File "C:\Users\sai dharan\anaconda3\lib\curses\__init__.py", line 13, in <module>
#     from _curses import *
# ModuleNotFoundError: No module named '_curses'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\sai dharan\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\sai dharan\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\sai dharan\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\sai dharan\anaconda3\lib\inspect.py", line 746, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\urwid\__init__.py", line 294, in __getattr__
#     real_module = importlib.import_module(self._moved_to)
#   File "C:\Users\sai dharan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\urwid\display\curses.py", line 27, in <module>
#     import curses
#   File "C:\Users\sai dharan\anaconda3\lib\curses\__init__.py", line 13, in <module>
#     from _curses import *
# ModuleNotFoundError: No module named '_curses'
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\sai dharan\AppData\Local\Temp\ipykernel_13680\1531362466.py", line 2, in <module>
#     from vit import ViTClassfier
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\vit\__init__.py", line 2, in <module>
#     from .application import Application
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\vit\application.py", line 20, in <module>
#     from vit.formatter_base import FormatterBase
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\vit\formatter_base.py", line 8, in <module>
#     from vit import util
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\vit\util.py", line 3, in <module>
#     import curses
#   File "C:\Users\sai dharan\anaconda3\lib\curses\__init__.py", line 13, in <module>
#     from _curses import *
# ModuleNotFoundError: No module named '_curses'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\sai dharan\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\sai dharan\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\sai dharan\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\sai dharan\anaconda3\lib\inspect.py", line 746, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\urwid\__init__.py", line 294, in __getattr__
#     real_module = importlib.import_module(self._moved_to)
#   File "C:\Users\sai dharan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\urwid\display\curses.py", line 27, in <module>
#     import curses
#   File "C:\Users\sai dharan\anaconda3\lib\curses\__init__.py", line 13, in <module>
#     from _curses import *
# ModuleNotFoundError: No module named '_curses'
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\sai dharan\AppData\Local\Temp\ipykernel_13680\1531362466.py", line 2, in <module>
#     from vit import ViTClassfier
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\vit\__init__.py", line 2, in <module>
#     from .application import Application
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\vit\application.py", line 20, in <module>
#     from vit.formatter_base import FormatterBase
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\vit\formatter_base.py", line 8, in <module>
#     from vit import util
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\vit\util.py", line 3, in <module>
#     import curses
#   File "C:\Users\sai dharan\anaconda3\lib\curses\__init__.py", line 13, in <module>
#     from _curses import *
# ModuleNotFoundError: No module named '_curses'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\sai dharan\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\sai dharan\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\sai dharan\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\sai dharan\anaconda3\lib\inspect.py", line 746, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\urwid\__init__.py", line 294, in __getattr__
#     real_module = importlib.import_module(self._moved_to)
#   File "C:\Users\sai dharan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\sai dharan\anaconda3\lib\site-packages\urwid\display\curses.py", line 27, in <module>
#     import curses
#   File "C:\Users\sai dharan\anaconda3\lib\curses\__init__.py", line 13, in <module>
#     from _curses import *
# ModuleNotFoundError: No module named '_curses'

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os


path = Path("/content/data/Training")
img_as_jpg = list(path.glob(r"*/*.jpg"))

# Counts the number of each categories in the dataset
file_count = list(map(lambda x: os.path.split(os.path.split(x)[0])[1],img_as_jpg))
glioma = file_count.count('glioma_tumor')
meningioma = file_count.count('meningioma_tumor')
no_tum = file_count.count('no_tumor')
pituitary = file_count.count('pituitary_tumor')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
labels = ['Glioma','Meningioma', 'Pituitary', 'No tumor']
count_train = [glioma, meningioma, pituitary, no_tum]
ax.bar(labels, count_train)
plt.show()

# %%
train = pd.concat([pd.Series(img_as_jpg,name="image").apply(str),pd.Series(file_count, name="type")],axis=1)
train = train.sample(frac=1).reset_index(drop=True)
print(np.shape(train))
# Out:
# (2880, 2)

# %%
train = pd.concat([pd.Series(img_as_jpg,name="image").apply(str),pd.Series(file_count, name="type")],axis=1)
train = train.sample(frac=1).reset_index(drop=True)
print(np.shape(train))
# Out:
# (2880, 2)

# %%
fig, axes = plt.subplots(4, 4, figsize=(8, 8))
fig.tight_layout()
counter = 0
for ax in axes.reshape(-1):
    ax.imshow(plt.imread(train["image"][counter]))
    ax.set_title(train["type"][counter])
    plt.rcParams["axes.grid"] = False
    counter = counter+1

# %%
hparams = AttrDict(
    image_size=(128, 128, 3),
    n_classes=4,
    batch_size=64,
)

ds = tf.keras.preprocessing.image_dataset_from_directory("/content/data/Training", image_size=hparams.image_size[:-1], batch_size=hparams.batch_size)
train_split = round(0.8 * ds.cardinality().numpy())
train_ds = ds.take(train_split); train_ds.class_names = ds.class_names
validation_ds = ds.skip(train_split); validation_ds.class_names = ds.class_names
# Out:
# Found 2880 files belonging to 4 classes.

# %%
strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    model = ViTClassfier(hparams.image_size, hparams.n_classes)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=["accuracy", BalancedSparseCategoricalAccuracy()]
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20088\1309756827.py in <module>
# ----> 1 strategy = tf.distribute.MirroredStrategy()
#       2
#       3 with strategy.scope():
#       4     model = ViTClassfier(hparams.image_size, hparams.n_classes)
#       5
#
# NameError: name 'tf' is not defined

# %%
model.fit(train_ds, epochs=20, validation_data=validation_ds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20088\538951678.py in <module>
# ----> 1 model.fit(train_ds, epochs=20, validation_data=validation_ds)
#
# NameError: name 'model' is not defined

# %%
_ = plot_grid_ds(validation_ds, size=(4, 4), model=model, figsize= (20,20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20088\34865186.py in <module>
# ----> 1 _ = plot_grid_ds(validation_ds, size=(4, 4), model=model, figsize= (20,20))
#
# NameError: name 'plot_grid_ds' is not defined

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

X, y_true = list(zip(*[(X, y) for (X, y) in validation_ds.unbatch().as_numpy_iterator()]))
y_hat = model.predict_on_batch(np.array(X)).argmax(axis=-1)
mat = confusion_matrix(y_true, y_hat)
mat
# Out:
# C:\Users\sai dharan\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20088\2972997997.py in <module>
#       3 from sklearn.metrics import confusion_matrix
#       4
# ----> 5 X, y_true = list(zip(*[(X, y) for (X, y) in validation_ds.unbatch().as_numpy_iterator()]))
#       6 y_hat = model.predict_on_batch(np.array(X)).argmax(axis=-1)
#       7 mat = confusion_matrix(y_true, y_hat)
#
# NameError: name 'validation_ds' is not defined

# %%
from sklearn.metrics import balanced_accuracy_score

acc = balanced_accuracy_score(y_true, y_hat)
print(f"Final accuracy on validation set : {acc:.3f}")
# Out:
# Final accuracy on validation set : 0.963

# %%
hparams = AttrDict(
    image_size=(128, 128, 3),
    n_classes=4,
    batch_size=64,
)

ds = tf.keras.preprocessing.image_dataset_from_directory("/content/data/Training", image_size=hparams.image_size[:-1], batch_size=hparams.batch_size)
ds1 = tf.keras.preprocessing.image_dataset_from_directory("/content/data/Testing", image_size=hparams.image_size[:-1], batch_size=hparams.batch_size)
train_split = round(0.8 * ds.cardinality().numpy())
train_ds = ds.take(train_split); train_ds.class_names = ds.class_names
validation_ds = ds1; validation_ds.class_names = ds1.class_names
# Out:
# Found 2880 files belonging to 4 classes.
# Found 394 files belonging to 4 classes.

# %%
strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    model = ViTClassfier(hparams.image_size, hparams.n_classes)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=["accuracy", BalancedSparseCategoricalAccuracy()]
    )

# %%
model.fit(train_ds, epochs=20, validation_data=validation_ds)
# Out:
# Epoch 1/20
# 36/36 [==============================] - 108s 3s/step - loss: 6.7581 - accuracy: 0.4748 - balanced_sparse_categorical_accuracy: 0.4671 - val_loss: 1.5717 - val_accuracy: 0.4036 - val_balanced_sparse_categorical_accuracy: 0.4340
# Epoch 2/20
# 36/36 [==============================] - 89s 2s/step - loss: 0.6132 - accuracy: 0.7708 - balanced_sparse_categorical_accuracy: 0.7603 - val_loss: 2.2321 - val_accuracy: 0.3883 - val_balanced_sparse_categorical_accuracy: 0.4344
# Epoch 3/20
# 36/36 [==============================] - 89s 2s/step - loss: 0.4774 - accuracy: 0.8086 - balanced_sparse_categorical_accuracy: 0.8110 - val_loss: 2.5099 - val_accuracy: 0.4036 - val_balanced_sparse_categorical_accuracy: 0.4405
# Epoch 4/20
# 36/36 [==============================] - 89s 2s/step - loss: 0.3969 - accuracy: 0.8420 - balanced_sparse_categorical_accuracy: 0.8505 - val_loss: 2.4229 - val_accuracy: 0.4797 - val_balanced_sparse_categorical_accuracy: 0.4633
# Epoch 5/20
# 36/36 [==============================] - 87s 2s/step - loss: 0.3208 - accuracy: 0.8772 - balanced_sparse_categorical_accuracy: 0.8776 - val_loss: 2.5270 - val_accuracy: 0.5457 - val_balanced_sparse_categorical_accuracy: 0.5615
# Epoch 6/20
# 36/36 [==============================] - 86s 2s/step - loss: 0.2469 - accuracy: 0.9002 - balanced_sparse_categorical_accuracy: 0.9036 - val_loss: 2.2423 - val_accuracy: 0.5888 - val_balanced_sparse_categorical_accuracy: 0.6141
# Epoch 7/20
# 36/36 [==============================] - 87s 2s/step - loss: 0.1846 - accuracy: 0.9336 - balanced_sparse_categorical_accuracy: 0.9362 - val_loss: 2.3660 - val_accuracy: 0.6447 - val_balanced_sparse_categorical_accuracy: 0.6367
# Epoch 8/20
# 36/36 [==============================] - 91s 3s/step - loss: 0.1197 - accuracy: 0.9549 - balanced_sparse_categorical_accuracy: 0.9552 - val_loss: 2.7622 - val_accuracy: 0.6777 - val_balanced_sparse_categorical_accuracy: 0.6857
# Epoch 9/20
# 36/36 [==============================] - 89s 2s/step - loss: 0.0817 - accuracy: 0.9679 - balanced_sparse_categorical_accuracy: 0.9664 - val_loss: 2.6994 - val_accuracy: 0.6726 - val_balanced_sparse_categorical_accuracy: 0.6536
# Epoch 10/20
# 36/36 [==============================] - 89s 2s/step - loss: 0.0531 - accuracy: 0.9796 - balanced_sparse_categorical_accuracy: 0.9787 - val_loss: 2.5364 - val_accuracy: 0.7132 - val_balanced_sparse_categorical_accuracy: 0.7190
# Epoch 11/20
# 36/36 [==============================] - 88s 2s/step - loss: 0.0762 - accuracy: 0.9735 - balanced_sparse_categorical_accuracy: 0.9750 - val_loss: 2.9181 - val_accuracy: 0.7056 - val_balanced_sparse_categorical_accuracy: 0.6990
# Epoch 12/20
# 36/36 [==============================] - 86s 2s/step - loss: 0.0608 - accuracy: 0.9783 - balanced_sparse_categorical_accuracy: 0.9803 - val_loss: 3.0039 - val_accuracy: 0.6904 - val_balanced_sparse_categorical_accuracy: 0.6564
# Epoch 13/20
# 36/36 [==============================] - 94s 3s/step - loss: 0.0383 - accuracy: 0.9865 - balanced_sparse_categorical_accuracy: 0.9861 - val_loss: 2.6305 - val_accuracy: 0.7310 - val_balanced_sparse_categorical_accuracy: 0.7264
# Epoch 14/20
# 36/36 [==============================] - 88s 2s/step - loss: 0.0363 - accuracy: 0.9878 - balanced_sparse_categorical_accuracy: 0.9877 - val_loss: 2.9553 - val_accuracy: 0.7107 - val_balanced_sparse_categorical_accuracy: 0.7174
# Epoch 15/20
# 36/36 [==============================] - 92s 3s/step - loss: 0.0322 - accuracy: 0.9891 - balanced_sparse_categorical_accuracy: 0.9903 - val_loss: 2.9925 - val_accuracy: 0.7386 - val_balanced_sparse_categorical_accuracy: 0.7185
# Epoch 16/20
# 36/36 [==============================] - 88s 2s/step - loss: 0.0247 - accuracy: 0.9931 - balanced_sparse_categorical_accuracy: 0.9931 - val_loss: 2.6131 - val_accuracy: 0.7462 - val_balanced_sparse_categorical_accuracy: 0.7476
# Epoch 17/20
# 36/36 [==============================] - 86s 2s/step - loss: 0.0267 - accuracy: 0.9913 - balanced_sparse_categorical_accuracy: 0.9914 - val_loss: 2.8791 - val_accuracy: 0.7284 - val_balanced_sparse_categorical_accuracy: 0.7205
# Epoch 18/20
# 36/36 [==============================] - 92s 3s/step - loss: 0.0551 - accuracy: 0.9831 - balanced_sparse_categorical_accuracy: 0.9814 - val_loss: 2.9621 - val_accuracy: 0.7284 - val_balanced_sparse_categorical_accuracy: 0.7190
# Epoch 19/20
# 36/36 [==============================] - 89s 2s/step - loss: 0.0360 - accuracy: 0.9865 - balanced_sparse_categorical_accuracy: 0.9881 - val_loss: 2.7615 - val_accuracy: 0.7234 - val_balanced_sparse_categorical_accuracy: 0.7147
# Epoch 20/20
# 36/36 [==============================] - 89s 2s/step - loss: 0.0380 - accuracy: 0.9891 - balanced_sparse_categorical_accuracy: 0.9900 - val_loss: 2.7378 - val_accuracy: 0.7386 - val_balanced_sparse_categorical_accuracy: 0.7328

# %%
_ = plot_grid_ds(validation_ds, size=(4, 4), model=model, figsize= (20,20))
# Out:
# 1/1 [==============================] - 1s 554ms/step

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

X, y_true = list(zip(*[(X, y) for (X, y) in validation_ds.unbatch().as_numpy_iterator()]))
y_hat = model.predict_on_batch(np.array(X)).argmax(axis=-1)
mat = confusion_matrix(y_true, y_hat)
mat
# Out:
# array([[ 18,  13,  61,   8],
#        [  0, 109,   6,   0],
#        [  0,   0, 105,   0],
#        [  0,   7,   8,  59]])

# %%
from sklearn.metrics import balanced_accuracy_score

acc = balanced_accuracy_score(y_true, y_hat)
print(f"Final accuracy on validation set : {acc:.3f}")
# Out:
# Final accuracy on validation set : 0.731

# %%
model.save("models/ViT_on_20_epochs.model")

# %%
# !rm -rf Vit_on_10_epochs.model

# %%
# %cd content
# Out:
# /content
